# %%
import pandas as pd

# %%
data = pd.read_csv('../data/processed/librispeech-gender-feats-test-clean.csv')

# %%
data.head()
# Out:
#        mean       std    median      kurt      skew       p25       p75  \
# 0  0.001320  0.000990  0.001060  1.112706  1.103305  0.000514  0.001902
# 1  0.001213  0.001019  0.000931  5.101538  1.762746  0.000449  0.001743
# 2  0.000972  0.000581  0.000937  0.186037  0.602367  0.000453  0.001334
# 3  0.001232  0.000835  0.001069  1.158657  1.024302  0.000550  0.001737
# 4  0.001140  0.000498  0.001055  4.192958  1.430040  0.000825  0.001345
#
#         iqr       ent   meanfun    maxfun    minfun  \
# 0  0.001388  6.060405  0.074934  0.141593  0.020025
# 1  0.001294  6.018126  0.064590  0.126984  0.020025
# 2  0.000881  6.142252  0.073639  0.161616  0.020025
# 3  0.001187  6.105671  0.075064  0.134454  0.020025
# 4  0.000520  6.238871  0.068247  0.173913  0.020025
#
#                                      path label
# 0  test-clean/61/70970/61-70970-0040.flac     M
# 1  test-clean/61/70970/61-70970-0017.flac     M
# 2  test-clean/61/70970/61-70970-0001.flac     M
# ...

# %%
import seaborn as sns
import matplotlib.pylab as plt

# %%
plt.figure(figsize=(10, 8))
feat = 'mean'
plt.title(feat)
sns.boxplot(data=data, x='label', y=feat)

# %%
plt.figure(figsize=(10, 8))
feat = 'std'
plt.title(feat)
sns.boxplot(data=data, x='label', y=feat)

# %%
plt.figure(figsize=(10, 8))
feat = 'skew'
plt.title(feat)
sns.boxplot(data=data, x='label', y=feat)

# %%
plt.figure(figsize=(10, 8))
feat = 'ent'
plt.title(feat)
sns.boxplot(data=data, x='label', y=feat)

# %%
plt.figure(figsize=(10, 8))
feat = 'p25'
plt.title(feat)
sns.boxplot(data=data, x='label', y=feat)

# %%
plt.figure(figsize=(10, 8))
feat = 'p75'
plt.title(feat)
sns.boxplot(data=data, x='label', y=feat)

# %%
plt.figure(figsize=(10, 8))
feat = 'iqr'
plt.title(feat)
sns.boxplot(data=data, x='label', y=feat)

# %%
plt.figure(figsize=(10, 8))
feat = 'meanfun'
plt.title(feat)
sns.boxplot(data=data, x='label', y=feat)

# %%
plt.figure(figsize=(10, 8))
feat = 'minfun'
plt.title(feat)
sns.boxplot(data=data, x='label', y=feat)

# %%
plt.figure(figsize=(10, 8))
feat = 'maxfun'
plt.title(feat)
sns.boxplot(data=data, x='label', y=feat)
